# %% [raw]
# ---
# layout: post
# codemirror: true
# title: SASS Inputs HW
# categories: [SASS]
# lesson_language: SASS
# lesson_topic: Inputs HW
# lesson_part: interactive
# lesson_type: lesson
# permalink: /sass/inputs-hw/
# author: 3rii0
# ---

# %% [markdown]
# ## Popcorn Hack (In-Class)
#
# **Refactored Changes:**
# - Replaced `style="width: 400px; border: 3px dashed purple;"` with `class="ocs_input large gradient"` (large, gradient-styled input).
# - Replaced the made-up `class="box"` with `class="ocs_input small"` (compact plain input).

# %% [markdown]
# ## Popcorn Hack (In-Class)
#
# {% capture popcorn_challenge %}
# Replace the inline styling and made-up class with the OCS input grammar: one large, gradient-styled input and one compact plain input, both using ocs_input.
# {% endcapture %}
#
# {% capture popcorn_code %}
# outputElement.innerHTML = `
#   <input type="text" class="ocs_input large gradient" placeholder="Search PVO resources...">
#   <br><br>
#   <input type="text" class="ocs_input small" placeholder="Volunteer First Name">
# `;
# {% endcapture %}
#
# {% include runners/ui.html
#   runner_id="sass-inputs-popcorn-hw"
#   challenge=popcorn_challenge
#   code=popcorn_code
#   height="220px"
#   output_height="180px"
#   autostart="true"
# %}

# %% [markdown]
# ## Homework Hack
#
# **Refactored Changes (Matching the 0.8-Point Rubric):**
# - **Input 1 (`Assistance Category`):** Removed `style="width: 500px; background: linear-gradient(to right, pink, purple);"` and replaced it with `class="ocs_input large gradient"` (`0.4` input grammar + `0.3` style modifier)[cite: 4].
# - **Input 2 (`Volunteer First Name`):** Removed the made-up `class="tinybox"` and replaced it with `class="ocs_input small"` (`0.4` input grammar)[cite: 4].
# - **Input 3 (`Volunteer Email`):** Removed `style="padding: 6px;"` and added `class="ocs_input medium"` while keeping `type="email"` (`0.4` input grammar)[cite: 4].
# - **Accessibility (`0.1` points):** Kept clear `placeholder` attributes on all three inputs[cite: 4].

# %% [markdown]
# ## Homework Hack
#
# {% capture homework_challenge %}
# Refactor the signup form by removing all inline styles and made-up classes, using ocs_input with appropriate size and style modifiers.
# {% endcapture %}
#
# {% capture homework_code %}
# outputElement.innerHTML = `
#   <input type="text" class="ocs_input large gradient" placeholder="Assistance Category">
#   <br><br>
#   <input type="text" class="ocs_input small" placeholder="Volunteer First Name">
#   <br><br>
#   <input type="email" class="ocs_input medium" placeholder="Volunteer Email">
# `;
# {% endcapture %}
#
# {% include runners/ui.html
#   runner_id="sass-inputs-homework-hw"
#   challenge=homework_challenge
#   code=homework_code
#   height="260px"
#   output_height="220px"
#   autostart="true"
# %}
